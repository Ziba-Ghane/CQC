# %% [markdown]
# # Set Variables

# %%
top_k = 20

# -------- method_way
method_way = "c" # a, b, c

if method_way == "a":
    bug_localization_accuracy = [1] # main data - th

elif method_way == "b":
    bug_localization_accuracy = [1] # main data - th

else:
    bug_localization_accuracy = [0.4, 0.5, 0.6, 0.7, 0.8]


# -------- dataset
# software_name = "Camel"
# software_name = "CloudStack"
# software_name = "Geode"
software_name = "Hbase"

# %%
print("bla: ", bug_localization_accuracy)
# Out:
# bla:  [0.4, 0.5, 0.6, 0.7, 0.8]

# %%
if software_name == "Camel":
    dataset_file_name = "Camel_Bugs - v.01"
    number_of_chunks = 3
    
elif software_name == "CloudStack":
    dataset_file_name = "CloudStack_Bugs - v.01"
    number_of_chunks = 8
    
elif software_name == "Geode":
    dataset_file_name = "Geode_Bug - v.01"
    number_of_chunks = 4
    
else:
    dataset_file_name = "Hbase_Bugs - v.03"
    number_of_chunks = 4

# %% [markdown]
# # Google Colab

# %%
# load data from google drive
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# !ls "/content/gdrive/My Drive/"
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'

# %%
# project folder path
project_folder = "gdrive/MyDrive/Colab Notebooks/paper/"

# data folder path
data_folder = "00- My Data/two-phased method/"

# dataset folder path
dataset_folder = software_name + "/"

# output folder path
output_folder = "01- Jupyter Notebook/two-phased method/00. Output/"

# %% [markdown]
# # Libs

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# # Config

# %%
mypaths = {
    "data": {
        "dataset_bugs":           project_folder + data_folder + dataset_folder + dataset_file_name + ".csv",
        "dataset_bugs_bla":       project_folder + data_folder + dataset_folder + "second/k={}/bla={}/" + "{} _ k={}, bla={}.csv",
        "dataset_bugs_bla_chunk": project_folder + data_folder + dataset_folder + "second/k={}/bla={}/" + "{} _ k={}, bla={} - {}.csv"
    }
}

preprocessing_params = {
    "data": {
        "dataset_bugs_bla": {
            # time_stamp is the time that we change the class for a bug fixing.
            # id stands for identifier
            "columns_name":   ["bug_report_id", "class_id", "time_stamp", "label"],
            "columns_dtype" : {0: "int64", 1: "int64", 2: "int64", 3:"int32"}
        }
    }
}

# %%
mypaths["data"]["dataset_bugs_bla"] = mypaths["data"]["dataset_bugs_bla"].format(
    top_k, 
    "{}", #bla
    dataset_file_name, 
    top_k, 
    "{}" #bla
)

# %%
mypaths
# Out:
# {'data': {'dataset_bugs': 'gdrive/MyDrive/Colab Notebooks/paper/00- My Data/two-phased method/Hbase/Hbase_Bugs - v.03.csv',
#   'dataset_bugs_bla': 'gdrive/MyDrive/Colab Notebooks/paper/00- My Data/two-phased method/Hbase/second/k=20/bla={}/Hbase_Bugs - v.03 _ k=20, bla={}.csv',
#   'dataset_bugs_bla_chunk': 'gdrive/MyDrive/Colab Notebooks/paper/00- My Data/two-phased method/Hbase/second/k={}/bla={}/{} _ k={}, bla={} - {}.csv'}}

# %% [markdown]
# # Read Files

# %% [markdown]
# ## df_data

# %%
df_data = {}

for bla in bug_localization_accuracy:
    print(mypaths["data"]["dataset_bugs_bla"])
    print(bla)
    temp = pd.read_csv(
        mypaths["data"]["dataset_bugs_bla"].format(bla, bla), 
        names=preprocessing_params["data"]["dataset_bugs_bla"]["columns_name"], 
        dtype=preprocessing_params["data"]["dataset_bugs_bla"]["columns_dtype"], 
        header=None
    )
    df_data[bla] = temp
# Out:
# gdrive/MyDrive/Colab Notebooks/paper/00- My Data/two-phased method/Hbase/second/k=20/bla={}/Hbase_Bugs - v.03 _ k=20, bla={}.csv
# 0.4
# gdrive/MyDrive/Colab Notebooks/paper/00- My Data/two-phased method/Hbase/second/k=20/bla={}/Hbase_Bugs - v.03 _ k=20, bla={}.csv
# 0.5
# gdrive/MyDrive/Colab Notebooks/paper/00- My Data/two-phased method/Hbase/second/k=20/bla={}/Hbase_Bugs - v.03 _ k=20, bla={}.csv
# 0.6
# gdrive/MyDrive/Colab Notebooks/paper/00- My Data/two-phased method/Hbase/second/k=20/bla={}/Hbase_Bugs - v.03 _ k=20, bla={}.csv
# 0.7
# gdrive/MyDrive/Colab Notebooks/paper/00- My Data/two-phased method/Hbase/second/k=20/bla={}/Hbase_Bugs - v.03 _ k=20, bla={}.csv
# 0.8

# %%
df_data
# Out:
# {0.4:        bug_report_id  class_id  time_stamp  label
#  0              41737    127912  1583149803      0
#  1              41737    125458  1583149803      0
#  2              41737    120384  1583149803      0
#  3              41737    128410  1583149803      0
#  4              41737    125502  1583149803      0
#  ...              ...       ...         ...    ...
#  43822          53953    130964  1285307201      0
#  43823          53953    131325  1285307201      0
#  43824          53953    131110  1285307201      0
#  43825          53953    131286  1285307201      0
#  43826          53953    130678  1285307201      0
#
#  [43827 rows x 4 columns],
#  0.5:        bug_report_id  class_id  time_stamp  label
#  0              41737    125548  1583149803      0
#  1              41737    131190  1583149803      0
#  2              41737    123720  1583149803      0
#  3              41737    129895  1583149803      0
#  4              41737    126774  1583149803      0
#  ...              ...       ...         ...    ...
#  43822          53953    130964  1285307201      0
#  43823          53953    131325  1285307201      0
#  43824          53953    131110  1285307201      0
#  43825          53953    131286  1285307201      0
#  43826          53953    130678  1285307201      0
#
#  [43827 rows x 4 columns],
#  0.6:        bug_report_id  class_id  time_stamp  label
#  0              41737    129951  1583149803      0
#  1              41737    128960  1583149803      0
#  2              41737    121588  1583149803      0
#  3              41737    128797  1583149803      0
#  4              41737    126065  1583149803      0
#  ...              ...       ...         ...    ...
#  43822          53947    131034  1285621324      0
#  43823          53947    130943  1285621324      1
#  43824          53949    131392  1285360841      0
#  43825          53949    130675  1285360841      0
#  43826          53951    131131  1285353282      0
#
#  [43827 rows x 4 columns],
#  0.7:        bug_report_id  class_id  time_stamp  label
#  0              41754    125102  1583135020      1
#  1              41754    128005  1583135020      0
#  2              41754    120239  1583135020      0
#  3              41754    120549  1583135020      1
#  4              41754    129950  1583135020     -1
#  ...              ...       ...         ...    ...
#  43822          53953    130964  1285307201      0
#  43823          53953    131325  1285307201      0
#  43824          53953    131110  1285307201      0
#  43825          53953    131286  1285307201      0
#  43826          53953    130678  1285307201      0
#
#  [43827 rows x 4 columns],
#  0.8:        bug_report_id  class_id  time_stamp  label
#  0              41751    121412  1583135020      1
#  1              41785    122260  1568083664     -1
#  2              41785    127245  1568083664      0
#  3              41785    123718  1568085244      0
#  4              41785    128632  1568085244     -1
#  ...              ...       ...         ...    ...
#  43822          53953    130964  1285307201      0
#  43823          53953    131325  1285307201      0
#  43824          53953    131110  1285307201      0
#  43825          53953    131286  1285307201      0
#  43826          53953    130678  1285307201      0
#
#  [43827 rows x 4 columns]}

# %% [markdown]
# # save

# %%
for bla, df in df_data.items():
    print("-" * 10, bla , "-" * 10)
    print("number of brid:    ", len(df.groupby("bug_report_id")))
    print("number of samples: ", len(df))
    
    # my_path = mypaths["data"]["dataset_bugs_bla"].format(bla)
    print("*" * 10)
    for j, sub_df_j in enumerate(np.array_split(df, number_of_chunks)):
        full_path = mypaths["data"]["dataset_bugs_bla_chunk"].format(
            top_k, 
            bla, 
            dataset_file_name, 
            top_k, 
            bla, 
            j
        )
        #print(full_path)
        sub_df_j.to_csv(full_path, header=False, index=False)
        print("number of sub samples: ", len(sub_df_j))
    print()
# Out:
# ---------- 0.4 ----------
# number of brid:     9201
# number of samples:  43827
# **********
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10956
#
# ---------- 0.5 ----------
# number of brid:     9201
# number of samples:  43827
# **********
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10956
#
# ---------- 0.6 ----------
# number of brid:     9201
# number of samples:  43827
# **********
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10956
#
# ---------- 0.7 ----------
# number of brid:     9201
# number of samples:  43827
# **********
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10956
#
# ---------- 0.8 ----------
# number of brid:     9201
# number of samples:  43827
# **********
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10957
# number of sub samples:  10956
